# %%
import matplotlib.pyplot as plt
import numpy as np

date = 17
gate = -60
current = "3.5n"

DOS = np.genfromtxt("/Users/wyatt/Desktop/BLGSweeps/1808" + str(date) + "_BLG_on_Si_" + current + "_" + str(gate) + "V_tipbias00001.dat",dtype=float,comments="#",usecols=(3,),skip_header=37)
Bias = np.genfromtxt("/Users/wyatt/Desktop/BLGSweeps/1808" + str(date) + "_BLG_on_Si_" + current + "_" + str(gate) + "V_tipbias00001.dat",dtype=float,comments="#",usecols=(0,),skip_header=37)

plt.figure(figsize=(8,8))
plt.plot(Bias,DOS,'gp',markersize=2)
plt.title("Gate Voltage = " + str(gate))
plt.xlabel("Sample/Tip Bias [V]")
plt.ylabel("DOS [arb units]")
plt.show

#plt.savefig("/Users/wyatt/Desktop/BLGSweeps/180810_BLG_on_Si_300p_" + str(gate) + "V.png")
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
